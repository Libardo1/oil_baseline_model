# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'grid', 'place']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# Notebook figures for model ...
# Creating figures for oilcompany 

place = 'outData/oilcompany/'

s = np.loadtxt(place+'s.txt')
vr = np.loadtxt(place+'vr.txt')
Xr = np.loadtxt(place+'Xr.txt')
PROFIT_Xr = np.loadtxt(place+'PROFIT_Xr.txt')
REVXr = np.loadtxt(place+'REVXr.txt')
fr = transpose(np.loadtxt(place+'fr.txt'))
Fr = np.loadtxt(place+'Fr.txt')

# %%
plot(s,Xr[0,], color='b', label='Low oil Prices')
plot(s,Xr[1,], color='r', label='High oil Prices')
ylabel('Oil Extraction')
xlabel('Oil Reserves')
title('Optimal Extraction Policy')
legend()

# %%
#plot(s,vr)
plot(s,vr[0,], color='b', label='Low oil Prices')
plot(s,vr[1,], color='r', label='High oil Prices')
ylabel('Value')
xlabel('Oil Reserves')
title('Optimal Value Function')
legend()

# %%
plot(s,PROFIT_Xr[0,], color='b', label='Low oil Prices')
plot(s,PROFIT_Xr[1,], color='r', label='High oil Prices')
ylabel('Value')
xlabel('Oil Reserves')
title('Optimal Profits')
legend()

# %%
plot(s,fr[0,], color='b', label='Low oil Prices')
plot(s,fr[1,], color='r', label='High oil Prices')
ylabel('Probability')
xlabel('Oil Reserves')
title('Steady State Density')
legend()

# %%
# loading data for constrained part

dgrid = np.loadtxt('outData/constrained/dgrid.txt')
p = np.loadtxt('outData/constrained/p.txt')
cT = np.loadtxt('outData/constrained/cT.txt')
c = np.loadtxt('outData/constrained/c.txt')
dpix = np.loadtxt('outData/constrained/dpix.txt')
dp = np.loadtxt('outData/constrained/dp.txt')

grid = linspace(1,len(dgrid),len(dgrid))

# %%
plot(dgrid,p[0,], color='b', label='1')
plot(dgrid,p[10,], color='r', label='150')
plot(dgrid,p[339,], color='y', label='340')
ylabel('')
xlabel('')
title('')
legend()

# %%
plot(dgrid,cT[0,], color='b', label='1')
plot(dgrid,cT[149,], color='r', label='150')
plot(dgrid,cT[339,], color='y', label='340')
ylabel('')
xlabel('')
title('')
legend()

# %%
plot(dgrid,dp[161,], color='b', label='1')
plot(dgrid,dp[162,], color='r', label='150')
plot(dgrid,dp[163,], color='y', label='340')
ylabel('')
xlabel('')
title('')
legend()
dp[10,].shape
# Out:
# (101,)

# %%
f = np.loadtxt('outData/oilcompany/f.txt')
plot(f)

# %%
x = np.loadtxt('outData/oilcompany/x.txt')
plot(x)

# %%
# ergodic results
p = np.loadtxt('outData/example/M_p.txt')
dp = np.loadtxt('outData/example/M_dp.txt')
slack = np.loadtxt('outData/example/M_slack.txt')
#plot(p[1,])
plot(p[50,])
plot(p[101,])

# %%
plot(dp[1,])
plot(dp[50,])
plot(dp[101,])

# %%
plot(p[1,])
plot(p[50,])
plot(p[101,])
